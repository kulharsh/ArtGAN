# %%
## image_resizer.py
# Importing required libraries
import os
import numpy as np
from PIL import Image

# Defining an image size and image channel
# We are going to resize all our images to 128X128 size and since our images are colored images
# We are setting our image channels to 3 (RGB)

IMAGE_SIZE = 128
IMAGE_CHANNELS = 3
IMAGE_DIR = 'drive/MyDrive/Colab Notebooks/potrait/'

# %%
# Defining image dir path. Change this if you have different directory
images_path = IMAGE_DIR 

training_data = []

# Iterating over the images inside the directory and resizing them using
# Pillow's resize method.
print('resizing...')

for filename in os.listdir(images_path):
    if "jpg" in filename:
      path = os.path.join(images_path, filename)
      image = Image.open(path).convert('RGB').resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)
      training_data.append(np.asarray(image))
print(len(training_data))    
training_data = np.reshape(training_data, (-1, IMAGE_SIZE, IMAGE_SIZE, IMAGE_CHANNELS))
training_data = training_data / 127.5 - 1

print('saving file...')
np.save('drive/MyDrive/Colab Notebooks/potrait/potrait_data.npy', training_data)
# Out:
# resizing...
# 1659
# saving file...

# %%
from keras.layers import Input, Reshape, Dropout, Dense, Flatten, BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
import os

# %%
training_data = np.load(os.path.join("drive/MyDrive/Colab Notebooks/potrait/", "potrait_data.npy"))

# %%
len(training_data)
# Out:
# 3203

# %%
def build_discriminator(image_shape):
  model = Sequential()
  model.add(Conv2D(32, kernel_size=3, strides=2,
  input_shape=image_shape, padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
  model.add(ZeroPadding2D(padding=((0, 1), (0, 1))))
  model.add(BatchNormalization(momentum=0.8))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.25))
  model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
  model.add(BatchNormalization(momentum=0.8))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.25))
  model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
  model.add(BatchNormalization(momentum=0.8))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.25))
  model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
  model.add(BatchNormalization(momentum=0.8))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(1, activation='sigmoid'))
  input_image = Input(shape=image_shape)
  validity = model(input_image)
  return Model(input_image, validity)

# %%
def build_generator(noise_size, channels):
    model = Sequential()
    model.add(Dense(4 * 4 * 256, activation="relu", input_dim=noise_size))
    model.add(Reshape((4, 4, 256)))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    for i in range(GENERATE_RES):
         model.add(UpSampling2D())
         model.add(Conv2D(256, kernel_size=3, padding="same"))
         model.add(BatchNormalization(momentum=0.8))
         model.add(Activation("relu"))
    model.summary()
    model.add(Conv2D(channels, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    input = Input(shape=(noise_size,))
    generated_image = model(input)
    
    return Model(input, generated_image)

# %%
def save_images(cnt, noise):
  image_array = np.full((
        PREVIEW_MARGIN + (PREVIEW_ROWS * (IMAGE_SIZE + PREVIEW_MARGIN)),
        PREVIEW_MARGIN + (PREVIEW_COLS * (IMAGE_SIZE + PREVIEW_MARGIN)), 3), 255, dtype=np.uint8)
  generated_images = generator.predict(noise)
  generated_images = 0.5 * generated_images + 0.5
  image_count = 0
  for row in range(PREVIEW_ROWS):
    for col in range(PREVIEW_COLS):
      r = row * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
      c = col * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
      image_array[r:r + IMAGE_SIZE, c:c + IMAGE_SIZE] = generated_images[image_count] * 255
      image_count += 1
      output_path = 'drive/MyDrive/Colab Notebooks/potrait/output/'
      if not os.path.exists(output_path):
          os.makedirs(output_path)
      filename = os.path.join(output_path, f"trained-{cnt}.png")
      im = Image.fromarray(image_array)
      im.save(filename)

# %%
# Preview image Frame
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 4
SAVE_FREQ = 50
# Size vector to generate images from
NOISE_SIZE = 100
# Configuration
EPOCHS = 10000 # number of iterations
BATCH_SIZE = 32
GENERATE_RES = 3
IMAGE_SIZE = 128 # rows/cols
IMAGE_CHANNELS = 3

# %%
image_shape = (IMAGE_SIZE, IMAGE_SIZE, IMAGE_CHANNELS)
optimizer = Adam(1.5e-4, 0.5)
discriminator = build_discriminator(image_shape)
discriminator.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
generator = build_generator(NOISE_SIZE, IMAGE_CHANNELS)
random_input = Input(shape=(NOISE_SIZE,))
generated_image = generator(random_input)
#discriminator.trainable = False
validity = discriminator(generated_image)
combined = Model(random_input, validity)
combined.compile(loss="binary_crossentropy",optimizer=optimizer, metrics=["accuracy"])
y_real = np.ones((BATCH_SIZE, 1))
y_fake = np.zeros((BATCH_SIZE, 1))
fixed_noise = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, NOISE_SIZE))
cnt = 1
for epoch in range(EPOCHS):
  idx = np.random.randint(0, training_data.shape[0], BATCH_SIZE)
  x_real = training_data[idx]

  noise= np.random.normal(0, 1, (BATCH_SIZE, NOISE_SIZE))
  x_fake = generator.predict(noise)

  discriminator_metric_real = discriminator.train_on_batch(x_real, y_real)
  discriminator_metric_generated = discriminator.train_on_batch(x_fake, y_fake)
  discriminator_metric = 0.5 * np.add(discriminator_metric_real, discriminator_metric_generated)
  generator_metric = combined.train_on_batch(noise, y_real)
  print("Training epoch...", epoch)
  if epoch % SAVE_FREQ == 0:
    save_images(cnt, fixed_noise)
    cnt += 1
    print(f"{epoch} epoch, Discriminator accuracy: {100*  discriminator_metric[1]}, Generator accuracy: {100 * generator_metric[1]}")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 4096)              413696
#
#  reshape_3 (Reshape)         (None, 4, 4, 256)         0
#
#  up_sampling2d_15 (UpSamplin  (None, 8, 8, 256)        0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_31 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_18 (Activation)  (None, 8, 8, 256)         0
#
#  up_sampling2d_16 (UpSamplin  (None, 16, 16, 256)      0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_32 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 256)       0
#
#  up_sampling2d_17 (UpSamplin  (None, 32, 32, 256)      0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_33 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 256)       0
#
#  up_sampling2d_18 (UpSamplin  (None, 64, 64, 256)      0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 256)       590080
#
#  batch_normalization_34 (Bat  (None, 64, 64, 256)      1024
#  chNormalization)
#
#  activation_21 (Activation)  (None, 64, 64, 256)       0
#
#  up_sampling2d_19 (UpSamplin  (None, 128, 128, 256)    0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 256)     590080
#
#  batch_normalization_35 (Bat  (None, 128, 128, 256)    1024
#  chNormalization)
#
#  activation_22 (Activation)  (None, 128, 128, 256)     0
#
# =================================================================
# Total params: 3,369,216
# Trainable params: 3,366,656
# Non-trainable params: 2,560
# _________________________________________________________________
# Training epoch... 0
# 0 epoch, Discriminator accuracy: 28.125, Generator accuracy: 100.0
# Training epoch... 1
# Training epoch... 2
# Training epoch... 3
# Training epoch... 4
# Training epoch... 5
# Training epoch... 6
# Training epoch... 7
# Training epoch... 8
# Training epoch... 9
# Training epoch... 10
# Training epoch... 11
# Training epoch... 12
# Training epoch... 13
# Training epoch... 14
# Training epoch... 15
# Training epoch... 16
# Training epoch... 17
# Training epoch... 18
# Training epoch... 19
# Training epoch... 20
# Training epoch... 21
# Training epoch... 22
# Training epoch... 23
# Training epoch... 24
# Training epoch... 25
# Training epoch... 26
# Training epoch... 27
# Training epoch... 28
# Training epoch... 29
# Training epoch... 30
# Training epoch... 31
# Training epoch... 32
# Training epoch... 33
# Training epoch... 34
# Training epoch... 35
# Training epoch... 36
# Training epoch... 37
# Training epoch... 38
# Training epoch... 39
# Training epoch... 40
# Training epoch... 41
# Training epoch... 42
# Training epoch... 43
# Training epoch... 44
# Training epoch... 45
# Training epoch... 46
# Training epoch... 47
# Training epoch... 48
# Training epoch... 49
# Training epoch... 50
# 50 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 3.125
# Training epoch... 51
# Training epoch... 52
# Training epoch... 53
# Training epoch... 54
# Training epoch... 55
# Training epoch... 56
# Training epoch... 57
# Training epoch... 58
# Training epoch... 59
# Training epoch... 60
# Training epoch... 61
# Training epoch... 62
# Training epoch... 63
# Training epoch... 64
# Training epoch... 65
# Training epoch... 66
# Training epoch... 67
# Training epoch... 68
# Training epoch... 69
# Training epoch... 70
# Training epoch... 71
# Training epoch... 72
# Training epoch... 73
# Training epoch... 74
# Training epoch... 75
# Training epoch... 76
# Training epoch... 77
# Training epoch... 78
# Training epoch... 79
# Training epoch... 80
# Training epoch... 81
# Training epoch... 82
# Training epoch... 83
# Training epoch... 84
# Training epoch... 85
# Training epoch... 86
# Training epoch... 87
# Training epoch... 88
# Training epoch... 89
# Training epoch... 90
# Training epoch... 91
# Training epoch... 92
# Training epoch... 93
# Training epoch... 94
# Training epoch... 95
# Training epoch... 96
# Training epoch... 97
# Training epoch... 98
# Training epoch... 99
# Training epoch... 100
# 100 epoch, Discriminator accuracy: 54.6875, Generator accuracy: 28.125
# Training epoch... 101
# Training epoch... 102
# Training epoch... 103
# Training epoch... 104
# Training epoch... 105
# Training epoch... 106
# Training epoch... 107
# Training epoch... 108
# Training epoch... 109
# Training epoch... 110
# Training epoch... 111
# Training epoch... 112
# Training epoch... 113
# Training epoch... 114
# Training epoch... 115
# Training epoch... 116
# Training epoch... 117
# Training epoch... 118
# Training epoch... 119
# Training epoch... 120
# Training epoch... 121
# Training epoch... 122
# Training epoch... 123
# Training epoch... 124
# Training epoch... 125
# Training epoch... 126
# Training epoch... 127
# Training epoch... 128
# Training epoch... 129
# Training epoch... 130
# Training epoch... 131
# Training epoch... 132
# Training epoch... 133
# Training epoch... 134
# Training epoch... 135
# Training epoch... 136
# Training epoch... 137
# Training epoch... 138
# Training epoch... 139
# Training epoch... 140
# Training epoch... 141
# Training epoch... 142
# Training epoch... 143
# Training epoch... 144
# Training epoch... 145
# Training epoch... 146
# Training epoch... 147
# Training epoch... 148
# Training epoch... 149
# Training epoch... 150
# 150 epoch, Discriminator accuracy: 82.8125, Generator accuracy: 93.75
# Training epoch... 151
# Training epoch... 152
# Training epoch... 153
# Training epoch... 154
# Training epoch... 155
# Training epoch... 156
# Training epoch... 157
# Training epoch... 158
# Training epoch... 159
# Training epoch... 160
# Training epoch... 161
# Training epoch... 162
# Training epoch... 163
# Training epoch... 164
# Training epoch... 165
# Training epoch... 166
# Training epoch... 167
# Training epoch... 168
# Training epoch... 169
# Training epoch... 170
# Training epoch... 171
# Training epoch... 172
# Training epoch... 173
# Training epoch... 174
# Training epoch... 175
# Training epoch... 176
# Training epoch... 177
# Training epoch... 178
# Training epoch... 179
# Training epoch... 180
# Training epoch... 181
# Training epoch... 182
# Training epoch... 183
# Training epoch... 184
# Training epoch... 185
# Training epoch... 186
# Training epoch... 187
# Training epoch... 188
# Training epoch... 189
# Training epoch... 190
# Training epoch... 191
# Training epoch... 192
# Training epoch... 193
# Training epoch... 194
# Training epoch... 195
# Training epoch... 196
# Training epoch... 197
# Training epoch... 198
# Training epoch... 199
# Training epoch... 200
# 200 epoch, Discriminator accuracy: 73.4375, Generator accuracy: 78.125
# Training epoch... 201
# Training epoch... 202
# Training epoch... 203
# Training epoch... 204
# Training epoch... 205
# Training epoch... 206
# Training epoch... 207
# Training epoch... 208
# Training epoch... 209
# Training epoch... 210
# Training epoch... 211
# Training epoch... 212
# Training epoch... 213
# Training epoch... 214
# Training epoch... 215
# Training epoch... 216
# Training epoch... 217
# Training epoch... 218
# Training epoch... 219
# Training epoch... 220
# Training epoch... 221
# Training epoch... 222
# Training epoch... 223
# Training epoch... 224
# Training epoch... 225
# Training epoch... 226
# Training epoch... 227
# Training epoch... 228
# Training epoch... 229
# Training epoch... 230
# Training epoch... 231
# Training epoch... 232
# Training epoch... 233
# Training epoch... 234
# Training epoch... 235
# Training epoch... 236
# Training epoch... 237
# Training epoch... 238
# Training epoch... 239
# Training epoch... 240
# Training epoch... 241
# Training epoch... 242
# Training epoch... 243
# Training epoch... 244
# Training epoch... 245
# Training epoch... 246
# Training epoch... 247
# Training epoch... 248
# Training epoch... 249
# Training epoch... 250
# 250 epoch, Discriminator accuracy: 31.25, Generator accuracy: 37.5
# Training epoch... 251
# Training epoch... 252
# Training epoch... 253
# Training epoch... 254
# Training epoch... 255
# Training epoch... 256
# Training epoch... 257
# Training epoch... 258
# Training epoch... 259
# Training epoch... 260
# Training epoch... 261
# Training epoch... 262
# Training epoch... 263
# Training epoch... 264
# Training epoch... 265
# Training epoch... 266
# Training epoch... 267
# Training epoch... 268
# Training epoch... 269
# Training epoch... 270
# Training epoch... 271
# Training epoch... 272
# Training epoch... 273
# Training epoch... 274
# Training epoch... 275
# Training epoch... 276
# Training epoch... 277
# Training epoch... 278
# Training epoch... 279
# Training epoch... 280
# Training epoch... 281
# Training epoch... 282
# Training epoch... 283
# Training epoch... 284
# Training epoch... 285
# Training epoch... 286
# Training epoch... 287
# Training epoch... 288
# Training epoch... 289
# Training epoch... 290
# Training epoch... 291
# Training epoch... 292
# Training epoch... 293
# Training epoch... 294
# Training epoch... 295
# Training epoch... 296
# Training epoch... 297
# Training epoch... 298
# Training epoch... 299
# Training epoch... 300
# 300 epoch, Discriminator accuracy: 42.1875, Generator accuracy: 53.125
# Training epoch... 301
# Training epoch... 302
# Training epoch... 303
# Training epoch... 304
# Training epoch... 305
# Training epoch... 306
# Training epoch... 307
# Training epoch... 308
# Training epoch... 309
# Training epoch... 310
# Training epoch... 311
# Training epoch... 312
# Training epoch... 313
# Training epoch... 314
# Training epoch... 315
# Training epoch... 316
# Training epoch... 317
# Training epoch... 318
# Training epoch... 319
# Training epoch... 320
# Training epoch... 321
# Training epoch... 322
# Training epoch... 323
# Training epoch... 324
# Training epoch... 325
# Training epoch... 326
# Training epoch... 327
# Training epoch... 328
# Training epoch... 329
# Training epoch... 330
# Training epoch... 331
# Training epoch... 332
# Training epoch... 333
# Training epoch... 334
# Training epoch... 335
# Training epoch... 336
# Training epoch... 337
# Training epoch... 338
# Training epoch... 339
# Training epoch... 340
# Training epoch... 341
# Training epoch... 342
# Training epoch... 343
# Training epoch... 344
# Training epoch... 345
# Training epoch... 346
# Training epoch... 347
# Training epoch... 348
# Training epoch... 349
# Training epoch... 350
# 350 epoch, Discriminator accuracy: 50.0, Generator accuracy: 15.625
# Training epoch... 351
# Training epoch... 352
# Training epoch... 353
# Training epoch... 354
# Training epoch... 355
# Training epoch... 356
# Training epoch... 357
# Training epoch... 358
# Training epoch... 359
# Training epoch... 360
# Training epoch... 361
# Training epoch... 362
# Training epoch... 363
# Training epoch... 364
# Training epoch... 365
# Training epoch... 366
# Training epoch... 367
# Training epoch... 368
# Training epoch... 369
# Training epoch... 370
# Training epoch... 371
# Training epoch... 372
# Training epoch... 373
# Training epoch... 374
# Training epoch... 375
# Training epoch... 376
# Training epoch... 377
# Training epoch... 378
# Training epoch... 379
# Training epoch... 380
# Training epoch... 381
# Training epoch... 382
# Training epoch... 383
# Training epoch... 384
# Training epoch... 385
# Training epoch... 386
# Training epoch... 387
# Training epoch... 388
# Training epoch... 389
# Training epoch... 390
# Training epoch... 391
# Training epoch... 392
# Training epoch... 393
# Training epoch... 394
# Training epoch... 395
# Training epoch... 396
# Training epoch... 397
# Training epoch... 398
# Training epoch... 399
# Training epoch... 400
# 400 epoch, Discriminator accuracy: 53.125, Generator accuracy: 28.125
# Training epoch... 401
# Training epoch... 402
# Training epoch... 403
# Training epoch... 404
# Training epoch... 405
# Training epoch... 406
# Training epoch... 407
# Training epoch... 408
# Training epoch... 409
# Training epoch... 410
# Training epoch... 411
# Training epoch... 412
# Training epoch... 413
# Training epoch... 414
# Training epoch... 415
# Training epoch... 416
# Training epoch... 417
# Training epoch... 418
# Training epoch... 419
# Training epoch... 420
# Training epoch... 421
# Training epoch... 422
# Training epoch... 423
# Training epoch... 424
# Training epoch... 425
# Training epoch... 426
# Training epoch... 427
# Training epoch... 428
# Training epoch... 429
# Training epoch... 430
# Training epoch... 431
# Training epoch... 432
# Training epoch... 433
# Training epoch... 434
# Training epoch... 435
# Training epoch... 436
# Training epoch... 437
# Training epoch... 438
# Training epoch... 439
# Training epoch... 440
# Training epoch... 441
# Training epoch... 442
# Training epoch... 443
# Training epoch... 444
# Training epoch... 445
# Training epoch... 446
# Training epoch... 447
# Training epoch... 448
# Training epoch... 449
# Training epoch... 450
# 450 epoch, Discriminator accuracy: 46.875, Generator accuracy: 31.25
# Training epoch... 451
# Training epoch... 452
# Training epoch... 453
# Training epoch... 454
# Training epoch... 455
# Training epoch... 456
# Training epoch... 457
# Training epoch... 458
# Training epoch... 459
# Training epoch... 460
# Training epoch... 461
# Training epoch... 462
# Training epoch... 463
# Training epoch... 464
# Training epoch... 465
# Training epoch... 466
# Training epoch... 467
# Training epoch... 468
# Training epoch... 469
# Training epoch... 470
# Training epoch... 471
# Training epoch... 472
# Training epoch... 473
# Training epoch... 474
# Training epoch... 475
# Training epoch... 476
# Training epoch... 477
# Training epoch... 478
# Training epoch... 479
# Training epoch... 480
# Training epoch... 481
# Training epoch... 482
# Training epoch... 483
# Training epoch... 484
# Training epoch... 485
# Training epoch... 486
# Training epoch... 487
# Training epoch... 488
# Training epoch... 489
# Training epoch... 490
# Training epoch... 491
# Training epoch... 492
# Training epoch... 493
# Training epoch... 494
# Training epoch... 495
# Training epoch... 496
# Training epoch... 497
# Training epoch... 498
# Training epoch... 499
# Training epoch... 500
# 500 epoch, Discriminator accuracy: 37.5, Generator accuracy: 34.375
# Training epoch... 501
# Training epoch... 502
# Training epoch... 503
# Training epoch... 504
# Training epoch... 505
# Training epoch... 506
# Training epoch... 507
# Training epoch... 508
# Training epoch... 509
# Training epoch... 510
# Training epoch... 511
# Training epoch... 512
# Training epoch... 513
# Training epoch... 514
# Training epoch... 515
# Training epoch... 516
# Training epoch... 517
# Training epoch... 518
# Training epoch... 519
# Training epoch... 520
# Training epoch... 521
# Training epoch... 522
# Training epoch... 523
# Training epoch... 524
# Training epoch... 525
# Training epoch... 526
# Training epoch... 527
# Training epoch... 528
# Training epoch... 529
# Training epoch... 530
# Training epoch... 531
# Training epoch... 532
# Training epoch... 533
# Training epoch... 534
# Training epoch... 535
# Training epoch... 536
# Training epoch... 537
# Training epoch... 538
# Training epoch... 539
# Training epoch... 540
# Training epoch... 541
# Training epoch... 542
# Training epoch... 543
# Training epoch... 544
# Training epoch... 545
# Training epoch... 546
# Training epoch... 547
# Training epoch... 548
# Training epoch... 549
# Training epoch... 550
# 550 epoch, Discriminator accuracy: 37.5, Generator accuracy: 34.375
# Training epoch... 551
# Training epoch... 552
# Training epoch... 553
# Training epoch... 554
# Training epoch... 555
# Training epoch... 556
# Training epoch... 557
# Training epoch... 558
# Training epoch... 559
# Training epoch... 560
# Training epoch... 561
# Training epoch... 562
# Training epoch... 563
# Training epoch... 564
# Training epoch... 565
# Training epoch... 566
# Training epoch... 567
# Training epoch... 568
# Training epoch... 569
# Training epoch... 570
# Training epoch... 571
# Training epoch... 572
# Training epoch... 573
# Training epoch... 574
# Training epoch... 575
# Training epoch... 576
# Training epoch... 577
# Training epoch... 578
# Training epoch... 579
# Training epoch... 580
# Training epoch... 581
# Training epoch... 582
# Training epoch... 583
# Training epoch... 584
# Training epoch... 585
# Training epoch... 586
# Training epoch... 587
# Training epoch... 588
# Training epoch... 589
# Training epoch... 590
# Training epoch... 591
# Training epoch... 592
# Training epoch... 593
# Training epoch... 594
# Training epoch... 595
# Training epoch... 596
# Training epoch... 597
# Training epoch... 598
# Training epoch... 599
# Training epoch... 600
# 600 epoch, Discriminator accuracy: 43.75, Generator accuracy: 62.5
# Training epoch... 601
# Training epoch... 602
# Training epoch... 603
# Training epoch... 604
# Training epoch... 605
# Training epoch... 606
# Training epoch... 607
# Training epoch... 608
# Training epoch... 609
# Training epoch... 610
# Training epoch... 611
# Training epoch... 612
# Training epoch... 613
# Training epoch... 614
# Training epoch... 615
# Training epoch... 616
# Training epoch... 617
# Training epoch... 618
# Training epoch... 619
# Training epoch... 620
# Training epoch... 621
# Training epoch... 622
# Training epoch... 623
# Training epoch... 624
# Training epoch... 625
# Training epoch... 626
# Training epoch... 627
# Training epoch... 628
# Training epoch... 629
# Training epoch... 630
# Training epoch... 631
# Training epoch... 632
# Training epoch... 633
# Training epoch... 634
# Training epoch... 635
# Training epoch... 636
# Training epoch... 637
# Training epoch... 638
# Training epoch... 639
# Training epoch... 640
# Training epoch... 641
# Training epoch... 642
# Training epoch... 643
# Training epoch... 644
# Training epoch... 645
# Training epoch... 646
# Training epoch... 647
# Training epoch... 648
# Training epoch... 649
# Training epoch... 650
# 650 epoch, Discriminator accuracy: 34.375, Generator accuracy: 46.875
# Training epoch... 651
# Training epoch... 652
# Training epoch... 653
# Training epoch... 654
# Training epoch... 655
# Training epoch... 656
# Training epoch... 657
# Training epoch... 658
# Training epoch... 659
# Training epoch... 660
# Training epoch... 661
# Training epoch... 662
# Training epoch... 663
# Training epoch... 664
# Training epoch... 665
# Training epoch... 666
# Training epoch... 667
# Training epoch... 668
# Training epoch... 669
# Training epoch... 670
# Training epoch... 671
# Training epoch... 672
# Training epoch... 673
# Training epoch... 674
# Training epoch... 675
# Training epoch... 676
# Training epoch... 677
# Training epoch... 678
# Training epoch... 679
# Training epoch... 680
# Training epoch... 681
# Training epoch... 682
# Training epoch... 683
# Training epoch... 684
# Training epoch... 685
# Training epoch... 686
# Training epoch... 687
# Training epoch... 688
# Training epoch... 689
# Training epoch... 690
# Training epoch... 691
# Training epoch... 692
# Training epoch... 693
# Training epoch... 694
# Training epoch... 695
# Training epoch... 696
# Training epoch... 697
# Training epoch... 698
# Training epoch... 699
# Training epoch... 700
# 700 epoch, Discriminator accuracy: 50.0, Generator accuracy: 40.625
# Training epoch... 701
# Training epoch... 702
# Training epoch... 703
# Training epoch... 704
# Training epoch... 705
# Training epoch... 706
# Training epoch... 707
# Training epoch... 708
# Training epoch... 709
# Training epoch... 710
# Training epoch... 711
# Training epoch... 712
# Training epoch... 713
# Training epoch... 714
# Training epoch... 715
# Training epoch... 716
# Training epoch... 717
# Training epoch... 718
# Training epoch... 719
# Training epoch... 720
# Training epoch... 721
# Training epoch... 722
# Training epoch... 723
# Training epoch... 724
# Training epoch... 725
# Training epoch... 726
# Training epoch... 727
# Training epoch... 728
# Training epoch... 729
# Training epoch... 730
# Training epoch... 731
# Training epoch... 732
# Training epoch... 733
# Training epoch... 734
# Training epoch... 735
# Training epoch... 736
# Training epoch... 737
# Training epoch... 738
# Training epoch... 739
# Training epoch... 740
# Training epoch... 741
# Training epoch... 742
# Training epoch... 743
# Training epoch... 744
# Training epoch... 745
# Training epoch... 746
# Training epoch... 747
# Training epoch... 748
# Training epoch... 749
# Training epoch... 750
# 750 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 53.125
# Training epoch... 751
# Training epoch... 752
# Training epoch... 753
# Training epoch... 754
# Training epoch... 755
# Training epoch... 756
# Training epoch... 757
# Training epoch... 758
# Training epoch... 759
# Training epoch... 760
# Training epoch... 761
# Training epoch... 762
# Training epoch... 763
# Training epoch... 764
# Training epoch... 765
# Training epoch... 766
# Training epoch... 767
# Training epoch... 768
# Training epoch... 769
# Training epoch... 770
# Training epoch... 771
# Training epoch... 772
# Training epoch... 773
# Training epoch... 774
# Training epoch... 775
# Training epoch... 776
# Training epoch... 777
# Training epoch... 778
# Training epoch... 779
# Training epoch... 780
# Training epoch... 781
# Training epoch... 782
# Training epoch... 783
# Training epoch... 784
# Training epoch... 785
# Training epoch... 786
# Training epoch... 787
# Training epoch... 788
# Training epoch... 789
# Training epoch... 790
# Training epoch... 791
# Training epoch... 792
# Training epoch... 793
# Training epoch... 794
# Training epoch... 795
# Training epoch... 796
# Training epoch... 797
# Training epoch... 798
# Training epoch... 799
# Training epoch... 800
# 800 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 34.375
# Training epoch... 801
# Training epoch... 802
# Training epoch... 803
# Training epoch... 804
# Training epoch... 805
# Training epoch... 806
# Training epoch... 807
# Training epoch... 808
# Training epoch... 809
# Training epoch... 810
# Training epoch... 811
# Training epoch... 812
# Training epoch... 813
# Training epoch... 814
# Training epoch... 815
# Training epoch... 816
# Training epoch... 817
# Training epoch... 818
# Training epoch... 819
# Training epoch... 820
# Training epoch... 821
# Training epoch... 822
# Training epoch... 823
# Training epoch... 824
# Training epoch... 825
# Training epoch... 826
# Training epoch... 827
# Training epoch... 828
# Training epoch... 829
# Training epoch... 830
# Training epoch... 831
# Training epoch... 832
# Training epoch... 833
# Training epoch... 834
# Training epoch... 835
# Training epoch... 836
# Training epoch... 837
# Training epoch... 838
# Training epoch... 839
# Training epoch... 840
# Training epoch... 841
# Training epoch... 842
# Training epoch... 843
# Training epoch... 844
# Training epoch... 845
# Training epoch... 846
# Training epoch... 847
# Training epoch... 848
# Training epoch... 849
# Training epoch... 850
# 850 epoch, Discriminator accuracy: 43.75, Generator accuracy: 50.0
# Training epoch... 851
# Training epoch... 852
# Training epoch... 853
# Training epoch... 854
# Training epoch... 855
# Training epoch... 856
# Training epoch... 857
# Training epoch... 858
# Training epoch... 859
# Training epoch... 860
# Training epoch... 861
# Training epoch... 862
# Training epoch... 863
# Training epoch... 864
# Training epoch... 865
# Training epoch... 866
# Training epoch... 867
# Training epoch... 868
# Training epoch... 869
# Training epoch... 870
# Training epoch... 871
# Training epoch... 872
# Training epoch... 873
# Training epoch... 874
# Training epoch... 875
# Training epoch... 876
# Training epoch... 877
# Training epoch... 878
# Training epoch... 879
# Training epoch... 880
# Training epoch... 881
# Training epoch... 882
# Training epoch... 883
# Training epoch... 884
# Training epoch... 885
# Training epoch... 886
# Training epoch... 887
# Training epoch... 888
# Training epoch... 889
# Training epoch... 890
# Training epoch... 891
# Training epoch... 892
# Training epoch... 893
# Training epoch... 894
# Training epoch... 895
# Training epoch... 896
# Training epoch... 897
# Training epoch... 898
# Training epoch... 899
# Training epoch... 900
# 900 epoch, Discriminator accuracy: 53.125, Generator accuracy: 90.625
# Training epoch... 901
# Training epoch... 902
# Training epoch... 903
# Training epoch... 904
# Training epoch... 905
# Training epoch... 906
# Training epoch... 907
# Training epoch... 908
# Training epoch... 909
# Training epoch... 910
# Training epoch... 911
# Training epoch... 912
# Training epoch... 913
# Training epoch... 914
# Training epoch... 915
# Training epoch... 916
# Training epoch... 917
# Training epoch... 918
# Training epoch... 919
# Training epoch... 920
# Training epoch... 921
# Training epoch... 922
# Training epoch... 923
# Training epoch... 924
# Training epoch... 925
# Training epoch... 926
# Training epoch... 927
# Training epoch... 928
# Training epoch... 929
# Training epoch... 930
# Training epoch... 931
# Training epoch... 932
# Training epoch... 933
# Training epoch... 934
# Training epoch... 935
# Training epoch... 936
# Training epoch... 937
# Training epoch... 938
# Training epoch... 939
# Training epoch... 940
# Training epoch... 941
# Training epoch... 942
# Training epoch... 943
# Training epoch... 944
# Training epoch... 945
# Training epoch... 946
# Training epoch... 947
# Training epoch... 948
# Training epoch... 949
# Training epoch... 950
# 950 epoch, Discriminator accuracy: 43.75, Generator accuracy: 15.625
# Training epoch... 951
# Training epoch... 952
# Training epoch... 953
# Training epoch... 954
# Training epoch... 955
# Training epoch... 956
# Training epoch... 957
# Training epoch... 958
# Training epoch... 959
# Training epoch... 960
# Training epoch... 961
# Training epoch... 962
# Training epoch... 963
# Training epoch... 964
# Training epoch... 965
# Training epoch... 966
# Training epoch... 967
# Training epoch... 968
# Training epoch... 969
# Training epoch... 970
# Training epoch... 971
# Training epoch... 972
# Training epoch... 973
# Training epoch... 974
# Training epoch... 975
# Training epoch... 976
# Training epoch... 977
# Training epoch... 978
# Training epoch... 979
# Training epoch... 980
# Training epoch... 981
# Training epoch... 982
# Training epoch... 983
# Training epoch... 984
# Training epoch... 985
# Training epoch... 986
# Training epoch... 987
# Training epoch... 988
# Training epoch... 989
# Training epoch... 990
# Training epoch... 991
# Training epoch... 992
# Training epoch... 993
# Training epoch... 994
# Training epoch... 995
# Training epoch... 996
# Training epoch... 997
# Training epoch... 998
# Training epoch... 999
# Training epoch... 1000
# 1000 epoch, Discriminator accuracy: 54.6875, Generator accuracy: 71.875
# Training epoch... 1001
# Training epoch... 1002
# Training epoch... 1003
# Training epoch... 1004
# Training epoch... 1005
# Training epoch... 1006
# Training epoch... 1007
# Training epoch... 1008
# Training epoch... 1009
# Training epoch... 1010
# Training epoch... 1011
# Training epoch... 1012
# Training epoch... 1013
# Training epoch... 1014
# Training epoch... 1015
# Training epoch... 1016
# Training epoch... 1017
# Training epoch... 1018
# Training epoch... 1019
# Training epoch... 1020
# Training epoch... 1021
# Training epoch... 1022
# Training epoch... 1023
# Training epoch... 1024
# Training epoch... 1025
# Training epoch... 1026
# Training epoch... 1027
# Training epoch... 1028
# Training epoch... 1029
# Training epoch... 1030
# Training epoch... 1031
# Training epoch... 1032
# Training epoch... 1033
# Training epoch... 1034
# Training epoch... 1035
# Training epoch... 1036
# Training epoch... 1037
# Training epoch... 1038
# Training epoch... 1039
# Training epoch... 1040
# Training epoch... 1041
# Training epoch... 1042
# Training epoch... 1043
# Training epoch... 1044
# Training epoch... 1045
# Training epoch... 1046
# Training epoch... 1047
# Training epoch... 1048
# Training epoch... 1049
# Training epoch... 1050
# 1050 epoch, Discriminator accuracy: 53.125, Generator accuracy: 75.0
# Training epoch... 1051
# Training epoch... 1052
# Training epoch... 1053
# Training epoch... 1054
# Training epoch... 1055
# Training epoch... 1056
# Training epoch... 1057
# Training epoch... 1058
# Training epoch... 1059
# Training epoch... 1060
# Training epoch... 1061
# Training epoch... 1062
# Training epoch... 1063
# Training epoch... 1064
# Training epoch... 1065
# Training epoch... 1066
# Training epoch... 1067
# Training epoch... 1068
# Training epoch... 1069
# Training epoch... 1070
# Training epoch... 1071
# Training epoch... 1072
# Training epoch... 1073
# Training epoch... 1074
# Training epoch... 1075
# Training epoch... 1076
# Training epoch... 1077
# Training epoch... 1078
# Training epoch... 1079
# Training epoch... 1080
# Training epoch... 1081
# Training epoch... 1082
# Training epoch... 1083
# Training epoch... 1084
# Training epoch... 1085
# Training epoch... 1086
# Training epoch... 1087
# Training epoch... 1088
# Training epoch... 1089
# Training epoch... 1090
# Training epoch... 1091
# Training epoch... 1092
# Training epoch... 1093
# Training epoch... 1094
# Training epoch... 1095
# Training epoch... 1096
# Training epoch... 1097
# Training epoch... 1098
# Training epoch... 1099
# Training epoch... 1100
# 1100 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 56.25
# Training epoch... 1101
# Training epoch... 1102
# Training epoch... 1103
# Training epoch... 1104
# Training epoch... 1105
# Training epoch... 1106
# Training epoch... 1107
# Training epoch... 1108
# Training epoch... 1109
# Training epoch... 1110
# Training epoch... 1111
# Training epoch... 1112
# Training epoch... 1113
# Training epoch... 1114
# Training epoch... 1115
# Training epoch... 1116
# Training epoch... 1117
# Training epoch... 1118
# Training epoch... 1119
# Training epoch... 1120
# Training epoch... 1121
# Training epoch... 1122
# Training epoch... 1123
# Training epoch... 1124
# Training epoch... 1125
# Training epoch... 1126
# Training epoch... 1127
# Training epoch... 1128
# Training epoch... 1129
# Training epoch... 1130
# Training epoch... 1131
# Training epoch... 1132
# Training epoch... 1133
# Training epoch... 1134
# Training epoch... 1135
# Training epoch... 1136
# Training epoch... 1137
# Training epoch... 1138
# Training epoch... 1139
# Training epoch... 1140
# Training epoch... 1141
# Training epoch... 1142
# Training epoch... 1143
# Training epoch... 1144
# Training epoch... 1145
# Training epoch... 1146
# Training epoch... 1147
# Training epoch... 1148
# Training epoch... 1149
# Training epoch... 1150
# 1150 epoch, Discriminator accuracy: 54.6875, Generator accuracy: 12.5
# Training epoch... 1151
# Training epoch... 1152
# Training epoch... 1153
# Training epoch... 1154
# Training epoch... 1155
# Training epoch... 1156
# Training epoch... 1157
# Training epoch... 1158
# Training epoch... 1159
# Training epoch... 1160
# Training epoch... 1161
# Training epoch... 1162
# Training epoch... 1163
# Training epoch... 1164
# Training epoch... 1165
# Training epoch... 1166
# Training epoch... 1167
# Training epoch... 1168
# Training epoch... 1169
# Training epoch... 1170
# Training epoch... 1171
# Training epoch... 1172
# Training epoch... 1173
# Training epoch... 1174
# Training epoch... 1175
# Training epoch... 1176
# Training epoch... 1177
# Training epoch... 1178
# Training epoch... 1179
# Training epoch... 1180
# Training epoch... 1181
# Training epoch... 1182
# Training epoch... 1183
# Training epoch... 1184
# Training epoch... 1185
# Training epoch... 1186
# Training epoch... 1187
# Training epoch... 1188
# Training epoch... 1189
# Training epoch... 1190
# Training epoch... 1191
# Training epoch... 1192
# Training epoch... 1193
# Training epoch... 1194
# Training epoch... 1195
# Training epoch... 1196
# Training epoch... 1197
# Training epoch... 1198
# Training epoch... 1199
# Training epoch... 1200
# 1200 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 15.625
# Training epoch... 1201
# Training epoch... 1202
# Training epoch... 1203
# Training epoch... 1204
# Training epoch... 1205
# Training epoch... 1206
# Training epoch... 1207
# Training epoch... 1208
# Training epoch... 1209
# Training epoch... 1210
# Training epoch... 1211
# Training epoch... 1212
# Training epoch... 1213
# Training epoch... 1214
# Training epoch... 1215
# Training epoch... 1216
# Training epoch... 1217
# Training epoch... 1218
# Training epoch... 1219
# Training epoch... 1220
# Training epoch... 1221
# Training epoch... 1222
# Training epoch... 1223
# Training epoch... 1224
# Training epoch... 1225
# Training epoch... 1226
# Training epoch... 1227
# Training epoch... 1228
# Training epoch... 1229
# Training epoch... 1230
# Training epoch... 1231
# Training epoch... 1232
# Training epoch... 1233
# Training epoch... 1234
# Training epoch... 1235
# Training epoch... 1236
# Training epoch... 1237
# Training epoch... 1238
# Training epoch... 1239
# Training epoch... 1240
# Training epoch... 1241
# Training epoch... 1242
# Training epoch... 1243
# Training epoch... 1244
# Training epoch... 1245
# Training epoch... 1246
# Training epoch... 1247
# Training epoch... 1248
# Training epoch... 1249
# Training epoch... 1250
# 1250 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 81.25
# Training epoch... 1251
# Training epoch... 1252
# Training epoch... 1253
# Training epoch... 1254
# Training epoch... 1255
# Training epoch... 1256
# Training epoch... 1257
# Training epoch... 1258
# Training epoch... 1259
# Training epoch... 1260
# Training epoch... 1261
# Training epoch... 1262
# Training epoch... 1263
# Training epoch... 1264
# Training epoch... 1265
# Training epoch... 1266
# Training epoch... 1267
# Training epoch... 1268
# Training epoch... 1269
# Training epoch... 1270
# Training epoch... 1271
# Training epoch... 1272
# Training epoch... 1273
# Training epoch... 1274
# Training epoch... 1275
# Training epoch... 1276
# Training epoch... 1277
# Training epoch... 1278
# Training epoch... 1279
# Training epoch... 1280
# Training epoch... 1281
# Training epoch... 1282
# Training epoch... 1283
# Training epoch... 1284
# Training epoch... 1285
# Training epoch... 1286
# Training epoch... 1287
# Training epoch... 1288
# Training epoch... 1289
# Training epoch... 1290
# Training epoch... 1291
# Training epoch... 1292
# Training epoch... 1293
# Training epoch... 1294
# Training epoch... 1295
# Training epoch... 1296
# Training epoch... 1297
# Training epoch... 1298
# Training epoch... 1299
# Training epoch... 1300
# 1300 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 34.375
# Training epoch... 1301
# Training epoch... 1302
# Training epoch... 1303
# Training epoch... 1304
# Training epoch... 1305
# Training epoch... 1306
# Training epoch... 1307
# Training epoch... 1308
# Training epoch... 1309
# Training epoch... 1310
# Training epoch... 1311
# Training epoch... 1312
# Training epoch... 1313
# Training epoch... 1314
# Training epoch... 1315
# Training epoch... 1316
# Training epoch... 1317
# Training epoch... 1318
# Training epoch... 1319
# Training epoch... 1320
# Training epoch... 1321
# Training epoch... 1322
# Training epoch... 1323
# Training epoch... 1324
# Training epoch... 1325
# Training epoch... 1326
# Training epoch... 1327
# Training epoch... 1328
# Training epoch... 1329
# Training epoch... 1330
# Training epoch... 1331
# Training epoch... 1332
# Training epoch... 1333
# Training epoch... 1334
# Training epoch... 1335
# Training epoch... 1336
# Training epoch... 1337
# Training epoch... 1338
# Training epoch... 1339
# Training epoch... 1340
# Training epoch... 1341
# Training epoch... 1342
# Training epoch... 1343
# Training epoch... 1344
# Training epoch... 1345
# Training epoch... 1346
# Training epoch... 1347
# Training epoch... 1348
# Training epoch... 1349
# Training epoch... 1350
# 1350 epoch, Discriminator accuracy: 54.6875, Generator accuracy: 50.0
# Training epoch... 1351
# Training epoch... 1352
# Training epoch... 1353
# Training epoch... 1354
# Training epoch... 1355
# Training epoch... 1356
# Training epoch... 1357
# Training epoch... 1358
# Training epoch... 1359
# Training epoch... 1360
# Training epoch... 1361
# Training epoch... 1362
# Training epoch... 1363
# Training epoch... 1364
# Training epoch... 1365
# Training epoch... 1366
# Training epoch... 1367
# Training epoch... 1368
# Training epoch... 1369
# Training epoch... 1370
# Training epoch... 1371
# Training epoch... 1372
# Training epoch... 1373
# Training epoch... 1374
# Training epoch... 1375
# Training epoch... 1376
# Training epoch... 1377
# Training epoch... 1378
# Training epoch... 1379
# Training epoch... 1380
# Training epoch... 1381
# Training epoch... 1382
# Training epoch... 1383
# Training epoch... 1384
# Training epoch... 1385
# Training epoch... 1386
# Training epoch... 1387
# Training epoch... 1388
# Training epoch... 1389
# Training epoch... 1390
# Training epoch... 1391
# Training epoch... 1392
# Training epoch... 1393
# Training epoch... 1394
# Training epoch... 1395
# Training epoch... 1396
# Training epoch... 1397
# Training epoch... 1398
# Training epoch... 1399
# Training epoch... 1400
# 1400 epoch, Discriminator accuracy: 37.5, Generator accuracy: 90.625
# Training epoch... 1401
# Training epoch... 1402
# Training epoch... 1403
# Training epoch... 1404
# Training epoch... 1405
# Training epoch... 1406
# Training epoch... 1407
# Training epoch... 1408
# Training epoch... 1409
# Training epoch... 1410
# Training epoch... 1411
# Training epoch... 1412
# Training epoch... 1413
# Training epoch... 1414
# Training epoch... 1415
# Training epoch... 1416
# Training epoch... 1417
# Training epoch... 1418
# Training epoch... 1419
# Training epoch... 1420
# Training epoch... 1421
# Training epoch... 1422
# Training epoch... 1423
# Training epoch... 1424
# Training epoch... 1425
# Training epoch... 1426
# Training epoch... 1427
# Training epoch... 1428
# Training epoch... 1429
# Training epoch... 1430
# Training epoch... 1431
# Training epoch... 1432
# Training epoch... 1433
# Training epoch... 1434
# Training epoch... 1435
# Training epoch... 1436
# Training epoch... 1437
# Training epoch... 1438
# Training epoch... 1439
# Training epoch... 1440
# Training epoch... 1441
# Training epoch... 1442
# Training epoch... 1443
# Training epoch... 1444
# Training epoch... 1445
# Training epoch... 1446
# Training epoch... 1447
# Training epoch... 1448
# Training epoch... 1449
# Training epoch... 1450
# 1450 epoch, Discriminator accuracy: 46.875, Generator accuracy: 96.875
# Training epoch... 1451
# Training epoch... 1452
# Training epoch... 1453
# Training epoch... 1454
# Training epoch... 1455
# Training epoch... 1456
# Training epoch... 1457
# Training epoch... 1458
# Training epoch... 1459
# Training epoch... 1460
# Training epoch... 1461
# Training epoch... 1462
# Training epoch... 1463
# Training epoch... 1464
# Training epoch... 1465
# Training epoch... 1466
# Training epoch... 1467
# Training epoch... 1468
# Training epoch... 1469
# Training epoch... 1470
# Training epoch... 1471
# Training epoch... 1472
# Training epoch... 1473
# Training epoch... 1474
# Training epoch... 1475
# Training epoch... 1476
# Training epoch... 1477
# Training epoch... 1478
# Training epoch... 1479
# Training epoch... 1480
# Training epoch... 1481
# Training epoch... 1482
# Training epoch... 1483
# Training epoch... 1484
# Training epoch... 1485
# Training epoch... 1486
# Training epoch... 1487
# Training epoch... 1488
# Training epoch... 1489
# Training epoch... 1490
# Training epoch... 1491
# Training epoch... 1492
# Training epoch... 1493
# Training epoch... 1494
# Training epoch... 1495
# Training epoch... 1496
# Training epoch... 1497
# Training epoch... 1498
# Training epoch... 1499
# Training epoch... 1500
# 1500 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 12.5
# Training epoch... 1501
# Training epoch... 1502
# Training epoch... 1503
# Training epoch... 1504
# Training epoch... 1505
# Training epoch... 1506
# Training epoch... 1507
# Training epoch... 1508
# Training epoch... 1509
# Training epoch... 1510
# Training epoch... 1511
# Training epoch... 1512
# Training epoch... 1513
# Training epoch... 1514
# Training epoch... 1515
# Training epoch... 1516
# Training epoch... 1517
# Training epoch... 1518
# Training epoch... 1519
# Training epoch... 1520
# Training epoch... 1521
# Training epoch... 1522
# Training epoch... 1523
# Training epoch... 1524
# Training epoch... 1525
# Training epoch... 1526
# Training epoch... 1527
# Training epoch... 1528
# Training epoch... 1529
# Training epoch... 1530
# Training epoch... 1531
# Training epoch... 1532
# Training epoch... 1533
# Training epoch... 1534
# Training epoch... 1535
# Training epoch... 1536
# Training epoch... 1537
# Training epoch... 1538
# Training epoch... 1539
# Training epoch... 1540
# Training epoch... 1541
# Training epoch... 1542
# Training epoch... 1543
# Training epoch... 1544
# Training epoch... 1545
# Training epoch... 1546
# Training epoch... 1547
# Training epoch... 1548
# Training epoch... 1549
# Training epoch... 1550
# 1550 epoch, Discriminator accuracy: 50.0, Generator accuracy: 87.5
# Training epoch... 1551
# Training epoch... 1552
# Training epoch... 1553
# Training epoch... 1554
# Training epoch... 1555
# Training epoch... 1556
# Training epoch... 1557
# Training epoch... 1558
# Training epoch... 1559
# Training epoch... 1560
# Training epoch... 1561
# Training epoch... 1562
# Training epoch... 1563
# Training epoch... 1564
# Training epoch... 1565
# Training epoch... 1566
# Training epoch... 1567
# Training epoch... 1568
# Training epoch... 1569
# Training epoch... 1570
# Training epoch... 1571
# Training epoch... 1572
# Training epoch... 1573
# Training epoch... 1574
# Training epoch... 1575
# Training epoch... 1576
# Training epoch... 1577
# Training epoch... 1578
# Training epoch... 1579
# Training epoch... 1580
# Training epoch... 1581
# Training epoch... 1582
# Training epoch... 1583
# Training epoch... 1584
# Training epoch... 1585
# Training epoch... 1586
# Training epoch... 1587
# Training epoch... 1588
# Training epoch... 1589
# Training epoch... 1590
# Training epoch... 1591
# Training epoch... 1592
# Training epoch... 1593
# Training epoch... 1594
# Training epoch... 1595
# Training epoch... 1596
# Training epoch... 1597
# Training epoch... 1598
# Training epoch... 1599
# Training epoch... 1600
# 1600 epoch, Discriminator accuracy: 50.0, Generator accuracy: 96.875
# Training epoch... 1601
# Training epoch... 1602
# Training epoch... 1603
# Training epoch... 1604
# Training epoch... 1605
# Training epoch... 1606
# Training epoch... 1607
# Training epoch... 1608
# Training epoch... 1609
# Training epoch... 1610
# Training epoch... 1611
# Training epoch... 1612
# Training epoch... 1613
# Training epoch... 1614
# Training epoch... 1615
# Training epoch... 1616
# Training epoch... 1617
# Training epoch... 1618
# Training epoch... 1619
# Training epoch... 1620
# Training epoch... 1621
# Training epoch... 1622
# Training epoch... 1623
# Training epoch... 1624
# Training epoch... 1625
# Training epoch... 1626
# Training epoch... 1627
# Training epoch... 1628
# Training epoch... 1629
# Training epoch... 1630
# Training epoch... 1631
# Training epoch... 1632
# Training epoch... 1633
# Training epoch... 1634
# Training epoch... 1635
# Training epoch... 1636
# Training epoch... 1637
# Training epoch... 1638
# Training epoch... 1639
# Training epoch... 1640
# Training epoch... 1641
# Training epoch... 1642
# Training epoch... 1643
# Training epoch... 1644
# Training epoch... 1645
# Training epoch... 1646
# Training epoch... 1647
# Training epoch... 1648
# Training epoch... 1649
# Training epoch... 1650
# 1650 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 18.75
# Training epoch... 1651
# Training epoch... 1652
# Training epoch... 1653
# Training epoch... 1654
# Training epoch... 1655
# Training epoch... 1656
# Training epoch... 1657
# Training epoch... 1658
# Training epoch... 1659
# Training epoch... 1660
# Training epoch... 1661
# Training epoch... 1662
# Training epoch... 1663
# Training epoch... 1664
# Training epoch... 1665
# Training epoch... 1666
# Training epoch... 1667
# Training epoch... 1668
# Training epoch... 1669
# Training epoch... 1670
# Training epoch... 1671
# Training epoch... 1672
# Training epoch... 1673
# Training epoch... 1674
# Training epoch... 1675
# Training epoch... 1676
# Training epoch... 1677
# Training epoch... 1678
# Training epoch... 1679
# Training epoch... 1680
# Training epoch... 1681
# Training epoch... 1682
# Training epoch... 1683
# Training epoch... 1684
# Training epoch... 1685
# Training epoch... 1686
# Training epoch... 1687
# Training epoch... 1688
# Training epoch... 1689
# Training epoch... 1690
# Training epoch... 1691
# Training epoch... 1692
# Training epoch... 1693
# Training epoch... 1694
# Training epoch... 1695
# Training epoch... 1696
# Training epoch... 1697
# Training epoch... 1698
# Training epoch... 1699
# Training epoch... 1700
# 1700 epoch, Discriminator accuracy: 53.125, Generator accuracy: 68.75
# Training epoch... 1701
# Training epoch... 1702
# Training epoch... 1703
# Training epoch... 1704
# Training epoch... 1705
# Training epoch... 1706
# Training epoch... 1707
# Training epoch... 1708
# Training epoch... 1709
# Training epoch... 1710
# Training epoch... 1711
# Training epoch... 1712
# Training epoch... 1713
# Training epoch... 1714
# Training epoch... 1715
# Training epoch... 1716
# Training epoch... 1717
# Training epoch... 1718
# Training epoch... 1719
# Training epoch... 1720
# Training epoch... 1721
# Training epoch... 1722
# Training epoch... 1723
# Training epoch... 1724
# Training epoch... 1725
# Training epoch... 1726
# Training epoch... 1727
# Training epoch... 1728
# Training epoch... 1729
# Training epoch... 1730
# Training epoch... 1731
# Training epoch... 1732
# Training epoch... 1733
# Training epoch... 1734
# Training epoch... 1735
# Training epoch... 1736
# Training epoch... 1737
# Training epoch... 1738
# Training epoch... 1739
# Training epoch... 1740
# Training epoch... 1741
# Training epoch... 1742
# Training epoch... 1743
# Training epoch... 1744
# Training epoch... 1745
# Training epoch... 1746
# Training epoch... 1747
# Training epoch... 1748
# Training epoch... 1749
# Training epoch... 1750
# 1750 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 93.75
# Training epoch... 1751
# Training epoch... 1752
# Training epoch... 1753
# Training epoch... 1754
# Training epoch... 1755
# Training epoch... 1756
# Training epoch... 1757
# Training epoch... 1758
# Training epoch... 1759
# Training epoch... 1760
# Training epoch... 1761
# Training epoch... 1762
# Training epoch... 1763
# Training epoch... 1764
# Training epoch... 1765
# Training epoch... 1766
# Training epoch... 1767
# Training epoch... 1768
# Training epoch... 1769
# Training epoch... 1770
# Training epoch... 1771
# Training epoch... 1772
# Training epoch... 1773
# Training epoch... 1774
# Training epoch... 1775
# Training epoch... 1776
# Training epoch... 1777
# Training epoch... 1778
# Training epoch... 1779
# Training epoch... 1780
# Training epoch... 1781
# Training epoch... 1782
# Training epoch... 1783
# Training epoch... 1784
# Training epoch... 1785
# Training epoch... 1786
# Training epoch... 1787
# Training epoch... 1788
# Training epoch... 1789
# Training epoch... 1790
# Training epoch... 1791
# Training epoch... 1792
# Training epoch... 1793
# Training epoch... 1794
# Training epoch... 1795
# Training epoch... 1796
# Training epoch... 1797
# Training epoch... 1798
# Training epoch... 1799
# Training epoch... 1800
# 1800 epoch, Discriminator accuracy: 50.0, Generator accuracy: 96.875
# Training epoch... 1801
# Training epoch... 1802
# Training epoch... 1803
# Training epoch... 1804
# Training epoch... 1805
# Training epoch... 1806
# Training epoch... 1807
# Training epoch... 1808
# Training epoch... 1809
# Training epoch... 1810
# Training epoch... 1811
# Training epoch... 1812
# Training epoch... 1813
# Training epoch... 1814
# Training epoch... 1815
# Training epoch... 1816
# Training epoch... 1817
# Training epoch... 1818
# Training epoch... 1819
# Training epoch... 1820
# Training epoch... 1821
# Training epoch... 1822
# Training epoch... 1823
# Training epoch... 1824
# Training epoch... 1825
# Training epoch... 1826
# Training epoch... 1827
# Training epoch... 1828
# Training epoch... 1829
# Training epoch... 1830
# Training epoch... 1831
# Training epoch... 1832
# Training epoch... 1833
# Training epoch... 1834
# Training epoch... 1835
# Training epoch... 1836
# Training epoch... 1837
# Training epoch... 1838
# Training epoch... 1839
# Training epoch... 1840
# Training epoch... 1841
# Training epoch... 1842
# Training epoch... 1843
# Training epoch... 1844
# Training epoch... 1845
# Training epoch... 1846
# Training epoch... 1847
# Training epoch... 1848
# ...
# Training epoch... 3630
# Training epoch... 3631
# Training epoch... 3632
# Training epoch... 3633
# Training epoch... 3634
# Training epoch... 3635
# Training epoch... 3636
# Training epoch... 3637
# Training epoch... 3638
# Training epoch... 3639
# Training epoch... 3640
# Training epoch... 3641
# Training epoch... 3642
# Training epoch... 3643
# Training epoch... 3644
# Training epoch... 3645
# Training epoch... 3646
# Training epoch... 3647
# Training epoch... 3648
# Training epoch... 3649
# Training epoch... 3650
# 3650 epoch, Discriminator accuracy: 46.875, Generator accuracy: 90.625
# Training epoch... 3651
# Training epoch... 3652
# Training epoch... 3653
# Training epoch... 3654
# Training epoch... 3655
# Training epoch... 3656
# Training epoch... 3657
# Training epoch... 3658
# Training epoch... 3659
# Training epoch... 3660
# Training epoch... 3661
# Training epoch... 3662
# Training epoch... 3663
# Training epoch... 3664
# Training epoch... 3665
# Training epoch... 3666
# Training epoch... 3667
# Training epoch... 3668
# Training epoch... 3669
# Training epoch... 3670
# Training epoch... 3671
# Training epoch... 3672
# Training epoch... 3673
# Training epoch... 3674
# Training epoch... 3675
# Training epoch... 3676
# Training epoch... 3677
# Training epoch... 3678
# Training epoch... 3679
# Training epoch... 3680
# Training epoch... 3681
# Training epoch... 3682
# Training epoch... 3683
# Training epoch... 3684
# Training epoch... 3685
# Training epoch... 3686
# Training epoch... 3687
# Training epoch... 3688
# Training epoch... 3689
# Training epoch... 3690
# Training epoch... 3691
# Training epoch... 3692
# Training epoch... 3693
# Training epoch... 3694
# Training epoch... 3695
# Training epoch... 3696
# Training epoch... 3697
# Training epoch... 3698
# Training epoch... 3699
# Training epoch... 3700
# 3700 epoch, Discriminator accuracy: 43.75, Generator accuracy: 93.75
# Training epoch... 3701
# Training epoch... 3702
# Training epoch... 3703
# Training epoch... 3704
# Training epoch... 3705
# Training epoch... 3706
# Training epoch... 3707
# Training epoch... 3708
# Training epoch... 3709
# Training epoch... 3710
# Training epoch... 3711
# Training epoch... 3712
# Training epoch... 3713
# Training epoch... 3714
# Training epoch... 3715
# Training epoch... 3716
# Training epoch... 3717
# Training epoch... 3718
# Training epoch... 3719
# Training epoch... 3720
# Training epoch... 3721
# Training epoch... 3722
# Training epoch... 3723
# Training epoch... 3724
# Training epoch... 3725
# Training epoch... 3726
# Training epoch... 3727
# Training epoch... 3728
# Training epoch... 3729
# Training epoch... 3730
# Training epoch... 3731
# Training epoch... 3732
# Training epoch... 3733
# Training epoch... 3734
# Training epoch... 3735
# Training epoch... 3736
# Training epoch... 3737
# Training epoch... 3738
# Training epoch... 3739
# Training epoch... 3740
# Training epoch... 3741
# Training epoch... 3742
# Training epoch... 3743
# Training epoch... 3744
# Training epoch... 3745
# Training epoch... 3746
# Training epoch... 3747
# Training epoch... 3748
# Training epoch... 3749
# Training epoch... 3750
# 3750 epoch, Discriminator accuracy: 46.875, Generator accuracy: 75.0
# Training epoch... 3751
# Training epoch... 3752
# Training epoch... 3753
# Training epoch... 3754
# Training epoch... 3755
# Training epoch... 3756
# Training epoch... 3757
# Training epoch... 3758
# Training epoch... 3759
# Training epoch... 3760
# Training epoch... 3761
# Training epoch... 3762
# Training epoch... 3763
# Training epoch... 3764
# Training epoch... 3765
# Training epoch... 3766
# Training epoch... 3767
# Training epoch... 3768
# Training epoch... 3769
# Training epoch... 3770
# Training epoch... 3771
# Training epoch... 3772
# Training epoch... 3773
# Training epoch... 3774
# Training epoch... 3775
# Training epoch... 3776
# Training epoch... 3777
# Training epoch... 3778
# Training epoch... 3779
# Training epoch... 3780
# Training epoch... 3781
# Training epoch... 3782
# Training epoch... 3783
# Training epoch... 3784
# Training epoch... 3785
# Training epoch... 3786
# Training epoch... 3787
# Training epoch... 3788
# Training epoch... 3789
# Training epoch... 3790
# Training epoch... 3791
# Training epoch... 3792
# Training epoch... 3793
# Training epoch... 3794
# Training epoch... 3795
# Training epoch... 3796
# Training epoch... 3797
# Training epoch... 3798
# Training epoch... 3799
# Training epoch... 3800
# 3800 epoch, Discriminator accuracy: 18.75, Generator accuracy: 90.625
# Training epoch... 3801
# Training epoch... 3802
# Training epoch... 3803
# Training epoch... 3804
# Training epoch... 3805
# Training epoch... 3806
# Training epoch... 3807
# Training epoch... 3808
# Training epoch... 3809
# Training epoch... 3810
# Training epoch... 3811
# Training epoch... 3812
# Training epoch... 3813
# Training epoch... 3814
# Training epoch... 3815
# Training epoch... 3816
# Training epoch... 3817
# Training epoch... 3818
# Training epoch... 3819
# Training epoch... 3820
# Training epoch... 3821
# Training epoch... 3822
# Training epoch... 3823
# Training epoch... 3824
# Training epoch... 3825
# Training epoch... 3826
# Training epoch... 3827
# Training epoch... 3828
# Training epoch... 3829
# Training epoch... 3830
# Training epoch... 3831
# Training epoch... 3832
# Training epoch... 3833
# Training epoch... 3834
# Training epoch... 3835
# Training epoch... 3836
# Training epoch... 3837
# Training epoch... 3838
# Training epoch... 3839
# Training epoch... 3840
# Training epoch... 3841
# Training epoch... 3842
# Training epoch... 3843
# Training epoch... 3844
# Training epoch... 3845
# Training epoch... 3846
# Training epoch... 3847
# Training epoch... 3848
# Training epoch... 3849
# Training epoch... 3850
# 3850 epoch, Discriminator accuracy: 43.75, Generator accuracy: 87.5
# Training epoch... 3851
# Training epoch... 3852
# Training epoch... 3853
# Training epoch... 3854
# Training epoch... 3855
# Training epoch... 3856
# Training epoch... 3857
# Training epoch... 3858
# Training epoch... 3859
# Training epoch... 3860
# Training epoch... 3861
# Training epoch... 3862
# Training epoch... 3863
# Training epoch... 3864
# Training epoch... 3865
# Training epoch... 3866
# Training epoch... 3867
# Training epoch... 3868
# Training epoch... 3869
# Training epoch... 3870
# Training epoch... 3871
# Training epoch... 3872
# Training epoch... 3873
# Training epoch... 3874
# Training epoch... 3875
# Training epoch... 3876
# Training epoch... 3877
# Training epoch... 3878
# Training epoch... 3879
# Training epoch... 3880
# Training epoch... 3881
# Training epoch... 3882
# Training epoch... 3883
# Training epoch... 3884
# Training epoch... 3885
# Training epoch... 3886
# Training epoch... 3887
# Training epoch... 3888
# Training epoch... 3889
# Training epoch... 3890
# Training epoch... 3891
# Training epoch... 3892
# Training epoch... 3893
# Training epoch... 3894
# Training epoch... 3895
# Training epoch... 3896
# Training epoch... 3897
# Training epoch... 3898
# Training epoch... 3899
# Training epoch... 3900
# 3900 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 96.875
# Training epoch... 3901
# Training epoch... 3902
# Training epoch... 3903
# Training epoch... 3904
# Training epoch... 3905
# Training epoch... 3906
# Training epoch... 3907
# Training epoch... 3908
# Training epoch... 3909
# Training epoch... 3910
# Training epoch... 3911
# Training epoch... 3912
# Training epoch... 3913
# Training epoch... 3914
# Training epoch... 3915
# Training epoch... 3916
# Training epoch... 3917
# Training epoch... 3918
# Training epoch... 3919
# Training epoch... 3920
# Training epoch... 3921
# Training epoch... 3922
# Training epoch... 3923
# Training epoch... 3924
# Training epoch... 3925
# Training epoch... 3926
# Training epoch... 3927
# Training epoch... 3928
# Training epoch... 3929
# Training epoch... 3930
# Training epoch... 3931
# Training epoch... 3932
# Training epoch... 3933
# Training epoch... 3934
# Training epoch... 3935
# Training epoch... 3936
# Training epoch... 3937
# Training epoch... 3938
# Training epoch... 3939
# Training epoch... 3940
# Training epoch... 3941
# Training epoch... 3942
# Training epoch... 3943
# Training epoch... 3944
# Training epoch... 3945
# Training epoch... 3946
# Training epoch... 3947
# Training epoch... 3948
# Training epoch... 3949
# Training epoch... 3950
# 3950 epoch, Discriminator accuracy: 50.0, Generator accuracy: 90.625
# Training epoch... 3951
# Training epoch... 3952
# Training epoch... 3953
# Training epoch... 3954
# Training epoch... 3955
# Training epoch... 3956
# Training epoch... 3957
# Training epoch... 3958
# Training epoch... 3959
# Training epoch... 3960
# Training epoch... 3961
# Training epoch... 3962
# Training epoch... 3963
# Training epoch... 3964
# Training epoch... 3965
# Training epoch... 3966
# Training epoch... 3967
# Training epoch... 3968
# Training epoch... 3969
# Training epoch... 3970
# Training epoch... 3971
# Training epoch... 3972
# Training epoch... 3973
# Training epoch... 3974
# Training epoch... 3975
# Training epoch... 3976
# Training epoch... 3977
# Training epoch... 3978
# Training epoch... 3979
# Training epoch... 3980
# Training epoch... 3981
# Training epoch... 3982
# Training epoch... 3983
# Training epoch... 3984
# Training epoch... 3985
# Training epoch... 3986
# Training epoch... 3987
# Training epoch... 3988
# Training epoch... 3989
# Training epoch... 3990
# Training epoch... 3991
# Training epoch... 3992
# Training epoch... 3993
# Training epoch... 3994
# Training epoch... 3995
# Training epoch... 3996
# Training epoch... 3997
# Training epoch... 3998
# Training epoch... 3999
# Training epoch... 4000
# 4000 epoch, Discriminator accuracy: 54.6875, Generator accuracy: 90.625
# Training epoch... 4001
# Training epoch... 4002
# Training epoch... 4003
# Training epoch... 4004
# Training epoch... 4005
# Training epoch... 4006
# Training epoch... 4007
# Training epoch... 4008
# Training epoch... 4009
# Training epoch... 4010
# Training epoch... 4011
# Training epoch... 4012
# Training epoch... 4013
# Training epoch... 4014
# Training epoch... 4015
# Training epoch... 4016
# Training epoch... 4017
# Training epoch... 4018
# Training epoch... 4019
# Training epoch... 4020
# Training epoch... 4021
# Training epoch... 4022
# Training epoch... 4023
# Training epoch... 4024
# Training epoch... 4025
# Training epoch... 4026
# Training epoch... 4027
# Training epoch... 4028
# Training epoch... 4029
# Training epoch... 4030
# Training epoch... 4031
# Training epoch... 4032
# Training epoch... 4033
# Training epoch... 4034
# Training epoch... 4035
# Training epoch... 4036
# Training epoch... 4037
# Training epoch... 4038
# Training epoch... 4039
# Training epoch... 4040
# Training epoch... 4041
# Training epoch... 4042
# Training epoch... 4043
# Training epoch... 4044
# Training epoch... 4045
# Training epoch... 4046
# Training epoch... 4047
# Training epoch... 4048
# Training epoch... 4049
# Training epoch... 4050
# 4050 epoch, Discriminator accuracy: 84.375, Generator accuracy: 96.875
# Training epoch... 4051
# Training epoch... 4052
# Training epoch... 4053
# Training epoch... 4054
# Training epoch... 4055
# Training epoch... 4056
# Training epoch... 4057
# Training epoch... 4058
# Training epoch... 4059
# Training epoch... 4060
# Training epoch... 4061
# Training epoch... 4062
# Training epoch... 4063
# Training epoch... 4064
# Training epoch... 4065
# Training epoch... 4066
# Training epoch... 4067
# Training epoch... 4068
# Training epoch... 4069
# Training epoch... 4070
# Training epoch... 4071
# Training epoch... 4072
# Training epoch... 4073
# Training epoch... 4074
# Training epoch... 4075
# Training epoch... 4076
# Training epoch... 4077
# Training epoch... 4078
# Training epoch... 4079
# Training epoch... 4080
# Training epoch... 4081
# Training epoch... 4082
# Training epoch... 4083
# Training epoch... 4084
# Training epoch... 4085
# Training epoch... 4086
# Training epoch... 4087
# Training epoch... 4088
# Training epoch... 4089
# Training epoch... 4090
# Training epoch... 4091
# Training epoch... 4092
# Training epoch... 4093
# Training epoch... 4094
# Training epoch... 4095
# Training epoch... 4096
# Training epoch... 4097
# Training epoch... 4098
# Training epoch... 4099
# Training epoch... 4100
# 4100 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 90.625
# Training epoch... 4101
# Training epoch... 4102
# Training epoch... 4103
# Training epoch... 4104
# Training epoch... 4105
# Training epoch... 4106
# Training epoch... 4107
# Training epoch... 4108
# Training epoch... 4109
# Training epoch... 4110
# Training epoch... 4111
# Training epoch... 4112
# Training epoch... 4113
# Training epoch... 4114
# Training epoch... 4115
# Training epoch... 4116
# Training epoch... 4117
# Training epoch... 4118
# Training epoch... 4119
# Training epoch... 4120
# Training epoch... 4121
# Training epoch... 4122
# Training epoch... 4123
# Training epoch... 4124
# Training epoch... 4125
# Training epoch... 4126
# Training epoch... 4127
# Training epoch... 4128
# Training epoch... 4129
# Training epoch... 4130
# Training epoch... 4131
# Training epoch... 4132
# Training epoch... 4133
# Training epoch... 4134
# Training epoch... 4135
# Training epoch... 4136
# Training epoch... 4137
# Training epoch... 4138
# Training epoch... 4139
# Training epoch... 4140
# Training epoch... 4141
# Training epoch... 4142
# Training epoch... 4143
# Training epoch... 4144
# Training epoch... 4145
# Training epoch... 4146
# Training epoch... 4147
# Training epoch... 4148
# Training epoch... 4149
# Training epoch... 4150
# 4150 epoch, Discriminator accuracy: 51.5625, Generator accuracy: 100.0
# Training epoch... 4151
# Training epoch... 4152
# Training epoch... 4153
# Training epoch... 4154
# Training epoch... 4155
# Training epoch... 4156
# Training epoch... 4157
# Training epoch... 4158
# Training epoch... 4159
# Training epoch... 4160
# Training epoch... 4161
# Training epoch... 4162
# Training epoch... 4163
# Training epoch... 4164
# Training epoch... 4165
# Training epoch... 4166
# Training epoch... 4167
# Training epoch... 4168
# Training epoch... 4169
# Training epoch... 4170
# Training epoch... 4171
# Training epoch... 4172
# Training epoch... 4173
# Training epoch... 4174
# Training epoch... 4175
# Training epoch... 4176
# Training epoch... 4177
# Training epoch... 4178
# Training epoch... 4179
# Training epoch... 4180
# Training epoch... 4181
# Training epoch... 4182
# Training epoch... 4183
# Training epoch... 4184
# Training epoch... 4185
# Training epoch... 4186
# Training epoch... 4187
# Training epoch... 4188
# Training epoch... 4189
# Training epoch... 4190
# Training epoch... 4191
# Training epoch... 4192
# Training epoch... 4193
# Training epoch... 4194
# Training epoch... 4195
# Training epoch... 4196
# Training epoch... 4197
# Training epoch... 4198
# Training epoch... 4199
# Training epoch... 4200
# 4200 epoch, Discriminator accuracy: 48.4375, Generator accuracy: 84.375
# Training epoch... 4201
# Training epoch... 4202
# Training epoch... 4203
# Training epoch... 4204
# Training epoch... 4205
# Training epoch... 4206
# Training epoch... 4207
# Training epoch... 4208
# Training epoch... 4209
# Training epoch... 4210
# Training epoch... 4211
# Training epoch... 4212
# Training epoch... 4213
# Training epoch... 4214
# Training epoch... 4215
# Training epoch... 4216
# Training epoch... 4217
# Training epoch... 4218
# Training epoch... 4219
# Training epoch... 4220
# Training epoch... 4221
# Training epoch... 4222
# Training epoch... 4223
# Training epoch... 4224
# Training epoch... 4225
# Training epoch... 4226
# Training epoch... 4227
# Training epoch... 4228
# Training epoch... 4229
# Training epoch... 4230
# Training epoch... 4231
# Training epoch... 4232
# Training epoch... 4233
# Training epoch... 4234
# Training epoch... 4235
# Training epoch... 4236
# Training epoch... 4237
# Training epoch... 4238
# Training epoch... 4239
# Training epoch... 4240
# Training epoch... 4241
# Training epoch... 4242
# Training epoch... 4243
# Training epoch... 4244
# Training epoch... 4245
# Training epoch... 4246
# Training epoch... 4247
# Training epoch... 4248
# Training epoch... 4249
# Training epoch... 4250
# 4250 epoch, Discriminator accuracy: 50.0, Generator accuracy: 96.875
# Training epoch... 4251
# Training epoch... 4252
# Training epoch... 4253
# Training epoch... 4254
# Training epoch... 4255
# Training epoch... 4256
# Training epoch... 4257
# Training epoch... 4258
# Training epoch... 4259
# Training epoch... 4260
# Training epoch... 4261
# Training epoch... 4262
# Training epoch... 4263
# Training epoch... 4264
# Training epoch... 4265
# Training epoch... 4266
# Training epoch... 4267
# Training epoch... 4268
# Training epoch... 4269
# Training epoch... 4270
# Training epoch... 4271
# Training epoch... 4272
# Training epoch... 4273
# Training epoch... 4274
# Training epoch... 4275
# Training epoch... 4276
# Training epoch... 4277
# Training epoch... 4278
# Training epoch... 4279
# Training epoch... 4280
# Training epoch... 4281
# Training epoch... 4282
# Training epoch... 4283
# Training epoch... 4284
